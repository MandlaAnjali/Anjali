# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.random.random(50)
x
# Out:
# array([0.86128433, 0.22368199, 0.17989828, 0.26413284, 0.00754104,
#        0.71906209, 0.4061742 , 0.08139849, 0.24584321, 0.29767051,
#        0.62749997, 0.25636949, 0.64804503, 0.12607985, 0.55626923,
#        0.60496712, 0.75328112, 0.91498502, 0.04078549, 0.21726565,
#        0.16953109, 0.71276331, 0.10732915, 0.28340365, 0.70762373,
#        0.02117146, 0.43861229, 0.91561823, 0.22922477, 0.61392764,
#        0.37344428, 0.69668424, 0.27772838, 0.76907616, 0.19409196,
#        0.54494431, 0.81435553, 0.32026767, 0.0109933 , 0.10181087,
#        0.44946981, 0.55453369, 0.75708926, 0.4110416 , 0.5431643 ,
#        0.18360584, 0.43013178, 0.7143293 , 0.65494624, 0.95671248])

# %%
y = np.log(x) +3*x
# x2 --> np.log(x)
# x1 --> x
# y = x2 + 3 x1
# y = 1*x2 + 3*x1 + 0

# %%
plt.plot(x,y,'o')

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression() 
LR.fit(x.reshape(-1,1),y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
LR.intercept_
# Out:
# -2.682961015718603

# %%
LR.coef_
# Out:
# array([6.42106121])

# %%
plt.plot(x,y,'ro')
plt.plot(x,LR.predict(x.reshape(-1,1)),'bo')

# %%
df = pd.DataFrame()
df['x1'] = x
df['x2'] = np.log(x)
df
# Out:
#           x1        x2
# 0   0.861284 -0.149331
# 1   0.223682 -1.497530
# 2   0.179898 -1.715364
# 3   0.264133 -1.331303
# 4   0.007541 -4.887395
# 5   0.719062 -0.329808
# 6   0.406174 -0.900973
# 7   0.081398 -2.508399
# 8   0.245843 -1.403061
# 9   0.297671 -1.211768
# 10  0.627500 -0.466012
# 11  0.256369 -1.361136
# 12  0.648045 -0.433795
# 13  0.126080 -2.070840
# 14  0.556269 -0.586503
# 15  0.604967 -0.502581
# 16  0.753281 -0.283317
# 17  0.914985 -0.088848
# 18  0.040785 -3.199429
# 19  0.217266 -1.526634
# 20  0.169531 -1.774719
# 21  0.712763 -0.338606
# 22  0.107329 -2.231855
# 23  0.283404 -1.260883
# 24  0.707624 -0.345843
# 25  0.021171 -3.855101
# 26  0.438612 -0.824139
# 27  0.915618 -0.088156
# 28  0.229225 -1.473052
# 29  0.613928 -0.487878
# 30  0.373444 -0.984986
# 31  0.696684 -0.361423
# 32  0.277728 -1.281112
# 33  0.769076 -0.262565
# 34  0.194092 -1.639423
# 35  0.544944 -0.607072
# 36  0.814356 -0.205358
# 37  0.320268 -1.138598
# 38  0.010993 -4.510469
# 39  0.101811 -2.284638
# 40  0.449470 -0.799687
# 41  0.554534 -0.589628
# 42  0.757089 -0.278274
# 43  0.411042 -0.889061
# 44  0.543164 -0.610343
# 45  0.183606 -1.694964
# 46  0.430132 -0.843664
# 47  0.714329 -0.336411
# 48  0.654946 -0.423202
# 49  0.956712 -0.044252

# %%
LR1 = LinearRegression()
LR1.fit(df,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# y = 1*x2 + 3*x1 + 0
print(LR1.intercept_,LR1.coef_)
# Out:
# -1.970645868709653e-15 [3. 1.]

# %%
plt.scatter(np.log(x),y)

# %%
plt.scatter(x**3,y)

# %%
# Polynomial
from sklearn.preprocessing import PolynomialFeatures
PF = PolynomialFeatures(degree=2)
PF.fit(df[['x1']])
PF.transform(df[['x1']])
# Out:
from sklearn.preprocessing import PolynomialFeatures
PF = PolynomialFeatures(degree=3)
PF.fit(df[['x1']])
poly_df = pd.DataFrame(PF.transform(df[['x1']]),columns=["x1","x2","x3","x4"])

# %%
poly_df
# Out:
#      x1        x2        x3            x4
# 0   1.0  0.861284  0.741811  6.389099e-01
# 1   1.0  0.223682  0.050034  1.119162e-02
# 2   1.0  0.179898  0.032363  5.822119e-03
# 3   1.0  0.264133  0.069766  1.842753e-02
# 4   1.0  0.007541  0.000057  4.288383e-07
# 5   1.0  0.719062  0.517050  3.717913e-01
# 6   1.0  0.406174  0.164977  6.700960e-02
# 7   1.0  0.081398  0.006626  5.393231e-04
# 8   1.0  0.245843  0.060439  1.485849e-02
# 9   1.0  0.297671  0.088608  2.637591e-02
# 10  1.0  0.627500  0.393756  2.470820e-01
# 11  1.0  0.256369  0.065725  1.684997e-02
# 12  1.0  0.648045  0.419962  2.721545e-01
# 13  1.0  0.126080  0.015896  2.004182e-03
# 14  1.0  0.556269  0.309435  1.721294e-01
# 15  1.0  0.604967  0.365985  2.214090e-01
# 16  1.0  0.753281  0.567432  4.274362e-01
# 17  1.0  0.914985  0.837198  7.660232e-01
# 18  1.0  0.040785  0.001663  6.784486e-05
# 19  1.0  0.217266  0.047204  1.025589e-02
# 20  1.0  0.169531  0.028741  4.872457e-03
# 21  1.0  0.712763  0.508032  3.621062e-01
# 22  1.0  0.107329  0.011520  1.236383e-03
# 23  1.0  0.283404  0.080318  2.276231e-02
# 24  1.0  0.707624  0.500731  3.543294e-01
# 25  1.0  0.021171  0.000448  9.489701e-06
# 26  1.0  0.438612  0.192381  8.438056e-02
# 27  1.0  0.915618  0.838357  7.676147e-01
# 28  1.0  0.229225  0.052544  1.204439e-02
# 29  1.0  0.613928  0.376907  2.313937e-01
# 30  1.0  0.373444  0.139461  5.208077e-02
# 31  1.0  0.696684  0.485369  3.381489e-01
# 32  1.0  0.277728  0.077133  2.142204e-02
# 33  1.0  0.769076  0.591478  4.548917e-01
# 34  1.0  0.194092  0.037672  7.311771e-03
# 35  1.0  0.544944  0.296964  1.618290e-01
# 36  1.0  0.814356  0.663175  5.400602e-01
# 37  1.0  0.320268  0.102571  3.285030e-02
# 38  1.0  0.010993  0.000121  1.328570e-06
# 39  1.0  0.101811  0.010365  1.055316e-03
# 40  1.0  0.449470  0.202023  9.080329e-02
# 41  1.0  0.554534  0.307508  1.705233e-01
# 42  1.0  0.757089  0.573184  4.339516e-01
# 43  1.0  0.411042  0.168955  6.944762e-02
# 44  1.0  0.543164  0.295027  1.602484e-01
# 45  1.0  0.183606  0.033711  6.189556e-03
# 46  1.0  0.430132  0.185013  7.958012e-02
# 47  1.0  0.714329  0.510266  3.644982e-01
# 48  1.0  0.654946  0.428955  2.809422e-01
# 49  1.0  0.956712  0.915299  8.756777e-01

# %%
poly_df['y'] = y

# %%
poly_df.corr()
# Out:
#     x1        x2        x3        x4         y
# x1 NaN       NaN       NaN       NaN       NaN
# x2 NaN  1.000000  0.966704  0.909921  0.953102
# x3 NaN  0.966704  1.000000  0.983736  0.861174
# x4 NaN  0.909921  0.983736  1.000000  0.783641
# y  NaN  0.953102  0.861174  0.783641  1.000000

# %% [markdown]
# - Regularization
#
# - x1,x2 -->are in same range
# - b1,b2
# - b1 =1
# - b2 =100000
